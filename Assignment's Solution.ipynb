# %% [markdown]
# # Assignment
#
# - Create your file in folder `BME11`
# - Visualize data from `datasets/2019_nCoV_data.csv`

# %% [markdown]
# 2019 Novel Coronavirus (2019-nCoV) is a virus (more specifically, a coronavirus) identified as the cause of an outbreak of respiratory illness first detected in Wuhan, China. Early on, many of the patients in the outbreak in Wuhan, China reportedly had some link to a large seafood and animal market, suggesting animal-to-person spread. However, a growing number of patients reportedly have not had exposure to animal markets, indicating person-to-person spread is occurring. At this time, it’s unclear how easily or sustainably this virus is spreading between people - CDC
#
# This dataset has daily level information on the number of affected cases, deaths and recovery from 2019 novel coronavirus.
#
# The data is available from 22 Jan 2020.
#
# source: [kaggle](https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset)

# %% [markdown]
# ## Group Members
#
# Wanwisa Silanan (maydayo) Student id: 5613364

# %% [markdown]
# ## 1. Load coronavirus file from `dataset/2019_nCoV_data.csv`

# %%
# %ls "./datasets"
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 85AE-BFC0
#
#  Directory of D:\Mproject\labclass\labclass-v2\datasets
#
# 02/06/2020  03:43 AM    <DIR>          .
# 02/06/2020  03:43 AM    <DIR>          ..
# 02/05/2020  07:15 AM            57,582 2019_nCoV_data.csv
# 06/19/2019  03:26 PM            15,354 DigiDB_digimonlist.csv
# 06/19/2019  03:58 PM         6,326,231 myanimelist.csv
# 06/19/2019  03:26 PM            26,898 starbucks_drinkMenu_expanded.csv
# 06/19/2019  03:26 PM            13,149 top-tracks-of-2017.csv
# 06/19/2019  03:26 PM           252,762 youtube.csv
#                6 File(s)      6,691,976 bytes
#                2 Dir(s)  742,123,991,040 bytes free

# %%
from os import path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.metrics import r2_score
import seaborn as sns
color = sns.color_palette()
sns.set()

# %%
def dp(dataFileName):
    '''
    This function is used to get full data path (dp) from data file name.
    '''
    return path.join('datasets', dataFileName)

# %%
fileName = '2019_nCoV_data.csv' # put your dataset's name here
df = pd.read_csv(dp(fileName), encoding='utf-8')
# import Data to array df

# %% [markdown]
# ## 2. Show dataframe

# %%
df
# Out:
#      Sno                 Date    Province/State               Country  \
# 0      1  01/22/2020 12:00:00             Anhui                 China
# 1      2  01/22/2020 12:00:00           Beijing                 China
# 2      3  01/22/2020 12:00:00         Chongqing                 China
# 3      4  01/22/2020 12:00:00            Fujian                 China
# 4      5  01/22/2020 12:00:00             Gansu                 China
# 5      6  01/22/2020 12:00:00         Guangdong                 China
# 6      7  01/22/2020 12:00:00           Guangxi                 China
# 7      8  01/22/2020 12:00:00           Guizhou                 China
# 8      9  01/22/2020 12:00:00            Hainan                 China
# 9     10  01/22/2020 12:00:00             Hebei                 China
# 10    11  01/22/2020 12:00:00      Heilongjiang                 China
# 11    12  01/22/2020 12:00:00             Henan                 China
# 12    13  01/22/2020 12:00:00         Hong Kong                 China
# 13    14  01/22/2020 12:00:00             Hubei                 China
# 14    15  01/22/2020 12:00:00             Hunan                 China
# 15    16  01/22/2020 12:00:00    Inner Mongolia                 China
# 16    17  01/22/2020 12:00:00           Jiangsu                 China
# 17    18  01/22/2020 12:00:00           Jiangxi                 China
# 18    19  01/22/2020 12:00:00             Jilin                 China
# 19    20  01/22/2020 12:00:00          Liaoning                 China
# 20    21  01/22/2020 12:00:00             Macau                 China
# 21    22  01/22/2020 12:00:00           Ningxia                 China
# 22    23  01/22/2020 12:00:00           Qinghai                 China
# 23    24  01/22/2020 12:00:00           Shaanxi                 China
# 24    25  01/22/2020 12:00:00          Shandong                 China
# 25    26  01/22/2020 12:00:00          Shanghai                 China
# 26    27  01/22/2020 12:00:00            Shanxi                 China
# 27    28  01/22/2020 12:00:00           Sichuan                 China
# 28    29  01/22/2020 12:00:00            Taiwan                 China
# 29    30  01/22/2020 12:00:00           Tianjin                 China
# ..   ...                  ...               ...                   ...
# 740  741  02/04/2020 22:00:00               NaN                France
# 741  742  02/04/2020 22:00:00               NaN  United Arab Emirates
# 742  743  02/04/2020 22:00:00   New South Wales             Australia
# 743  744  02/04/2020 22:00:00          Victoria             Australia
# 744  745  02/04/2020 22:00:00        Queensland             Australia
# 745  746  02/04/2020 22:00:00               NaN                 India
# 746  747  02/04/2020 22:00:00   South Australia             Australia
# 747  748  02/04/2020 22:00:00       Toronto, ON                Canada
# 748  749  02/04/2020 22:00:00               NaN                 Italy
# 749  750  02/04/2020 22:00:00               NaN           Philippines
# 750  751  02/04/2020 22:00:00               NaN                Russia
# 751  752  02/04/2020 22:00:00               NaN                    UK
# 752  753  02/04/2020 22:00:00       Chicago, IL                    US
# 753  754  02/04/2020 22:00:00    San Benito, CA                    US
# 754  755  02/04/2020 22:00:00   Santa Clara, CA                    US
# 755  756  02/04/2020 22:00:00               NaN               Belgium
# 756  757  02/04/2020 22:00:00               NaN              Cambodia
# 757  758  02/04/2020 22:00:00  British Columbia                Canada
# 758  759  02/04/2020 22:00:00        London, ON                Canada
# 759  760  02/04/2020 22:00:00               NaN               Finland
# 760  761  02/04/2020 22:00:00             Tibet        Mainland China
# 761  762  02/04/2020 22:00:00               NaN                 Nepal
# 762  763  02/04/2020 22:00:00               NaN                 Spain
# 763  764  02/04/2020 22:00:00               NaN             Sri Lanka
# 764  765  02/04/2020 22:00:00               NaN                Sweden
# 765  766  02/04/2020 22:00:00        Boston, MA                    US
# 766  767  02/04/2020 22:00:00   Los Angeles, CA                    US
# 767  768  02/04/2020 22:00:00        Orange, CA                    US
# 768  769  02/04/2020 22:00:00       Seattle, WA                    US
# 769  770  02/04/2020 22:00:00         Tempe, AZ                    US
#
#              Last Update  Confirmed  Deaths  Recovered
# 0    01/22/2020 12:00:00        1.0     0.0        0.0
# 1    01/22/2020 12:00:00       14.0     0.0        0.0
# 2    01/22/2020 12:00:00        6.0     0.0        0.0
# 3    01/22/2020 12:00:00        1.0     0.0        0.0
# 4    01/22/2020 12:00:00        0.0     0.0        0.0
# 5    01/22/2020 12:00:00       26.0     0.0        0.0
# 6    01/22/2020 12:00:00        2.0     0.0        0.0
# 7    01/22/2020 12:00:00        1.0     0.0        0.0
# 8    01/22/2020 12:00:00        4.0     0.0        0.0
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 770 entries, 0 to 769
# Data columns (total 8 columns):
# Sno               770 non-null int64
# Date              770 non-null object
# Province/State    585 non-null object
# Country           770 non-null object
# Last Update       770 non-null object
# Confirmed         770 non-null float64
# Deaths            770 non-null float64
# Recovered         770 non-null float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 48.2+ KB

# %% [markdown]
# ## 3. Show how many countries that affected by virus

# %%
# Countries affected

countries = df['Country'].unique().tolist()
print(countries)

print("\nTotal countries affected by virus: ",len(countries))
# Out:
# ['China', 'US', 'Japan', 'Thailand', 'South Korea', 'Mainland China', 'Hong Kong', 'Macau', 'Taiwan', 'Singapore', 'Philippines', 'Malaysia', 'Vietnam', 'Australia', 'Mexico', 'Brazil', 'France', 'Nepal', 'Canada', 'Cambodia', 'Sri Lanka', 'Ivory Coast', 'Germany', 'Finland', 'United Arab Emirates', 'India', 'Italy', 'Sweden', 'Russia', 'Spain', 'UK', 'Belgium']
#
# Total countries affected by virus:  32

# %% [markdown]
# China and Mainland China have been reported separately

# %%
#Combining China and Mainland China cases

df['Country'].replace({'Mainland China':'China'},inplace=True)
countries = df['Country'].unique().tolist()
print(countries)
print("\nTotal countries affected by virus: ",len(countries))
# Out:
# ['China', 'US', 'Japan', 'Thailand', 'South Korea', 'Hong Kong', 'Macau', 'Taiwan', 'Singapore', 'Philippines', 'Malaysia', 'Vietnam', 'Australia', 'Mexico', 'Brazil', 'France', 'Nepal', 'Canada', 'Cambodia', 'Sri Lanka', 'Ivory Coast', 'Germany', 'Finland', 'United Arab Emirates', 'India', 'Italy', 'Sweden', 'Russia', 'Spain', 'UK', 'Belgium']
#
# Total countries affected by virus:  31

# %% [markdown]
# ## 4. Show and visualize total number of confirmed, deaths & recovered cases in each countries

# %%
df_sum_country = df.groupby(['Country']).sum().drop(['Sno'],axis=1).sort_values(by=['Confirmed'],ascending=False)
df_sum_country
# Out:
#                       Confirmed  Deaths  Recovered
# Country
# China                  121935.0  2641.0     3212.0
# Thailand                  176.0     0.0       46.0
# Japan                     143.0     0.0       10.0
# Singapore                 137.0     0.0        0.0
# Hong Kong                 130.0     1.0        0.0
# South Korea               100.0     0.0        0.0
# Australia                  92.0     0.0       12.0
# Taiwan                     92.0     0.0        0.0
# Macau                      79.0     0.0        0.0
# US                         78.0     0.0        0.0
# Malaysia                   75.0     0.0        0.0
# Germany                    62.0     0.0        0.0
# France                     55.0     0.0        0.0
# Vietnam                    46.0     0.0        4.0
# United Arab Emirates       31.0     0.0        0.0
# Canada                     29.0     0.0        0.0
# Italy                      12.0     0.0        0.0
# Nepal                      11.0     0.0        0.0
# India                      11.0     0.0        0.0
# Philippines                10.0     4.0        0.0
# Russia                     10.0     0.0        0.0
# UK                         10.0     0.0        0.0
# Sri Lanka                   9.0     0.0        0.0
# Cambodia                    9.0     0.0        0.0
# Finland                     7.0     0.0        0.0
# Spain                       5.0     0.0        0.0
# Sweden                      5.0     0.0        0.0
# Belgium                     1.0     0.0        0.0
# Mexico                      0.0     0.0        0.0
# Ivory Coast                 0.0     0.0        0.0
# Brazil                      0.0     0.0        0.0

# %%
sns.set(color_codes=True)
df_sum_country.plot(kind='bar',figsize=(20,10), fontsize=12,logy=True) #have to disply in log scale

# %% [markdown]
# ## 5. Show and visualize global spread of the coronavirus over time

# %%
'''
# Convert Last Update column to datetime64 format
df['Date'] = df['Date'].apply(pd.to_datetime)

#Set Date column as the index column.
df.set_index('Last Update', inplace=True)
df.head()
'''
# Out:
#                      Sno                Date Province/State Country  \
# Last Update
# 01/22/2020 12:00:00    1 2020-01-22 12:00:00          Anhui   China
# 01/22/2020 12:00:00    2 2020-01-22 12:00:00        Beijing   China
# 01/22/2020 12:00:00    3 2020-01-22 12:00:00      Chongqing   China
# 01/22/2020 12:00:00    4 2020-01-22 12:00:00         Fujian   China
# 01/22/2020 12:00:00    5 2020-01-22 12:00:00          Gansu   China
#
#                      Confirmed  Deaths  Recovered
# Last Update
# 01/22/2020 12:00:00        1.0     0.0        0.0
# 01/22/2020 12:00:00       14.0     0.0        0.0
# 01/22/2020 12:00:00        6.0     0.0        0.0
# 01/22/2020 12:00:00        1.0     0.0        0.0
# 01/22/2020 12:00:00        0.0     0.0        0.0

# %%
df['date'] = df['Date'].dt.date
df
# Out:
#                      Sno                Date    Province/State  \
# Last Update
# 01/22/2020 12:00:00    1 2020-01-22 12:00:00             Anhui
# 01/22/2020 12:00:00    2 2020-01-22 12:00:00           Beijing
# 01/22/2020 12:00:00    3 2020-01-22 12:00:00         Chongqing
# 01/22/2020 12:00:00    4 2020-01-22 12:00:00            Fujian
# 01/22/2020 12:00:00    5 2020-01-22 12:00:00             Gansu
# 01/22/2020 12:00:00    6 2020-01-22 12:00:00         Guangdong
# 01/22/2020 12:00:00    7 2020-01-22 12:00:00           Guangxi
# 01/22/2020 12:00:00    8 2020-01-22 12:00:00           Guizhou
# 01/22/2020 12:00:00    9 2020-01-22 12:00:00            Hainan
# 01/22/2020 12:00:00   10 2020-01-22 12:00:00             Hebei
# 01/22/2020 12:00:00   11 2020-01-22 12:00:00      Heilongjiang
# 01/22/2020 12:00:00   12 2020-01-22 12:00:00             Henan
# 01/22/2020 12:00:00   13 2020-01-22 12:00:00         Hong Kong
# 01/22/2020 12:00:00   14 2020-01-22 12:00:00             Hubei
# 01/22/2020 12:00:00   15 2020-01-22 12:00:00             Hunan
# 01/22/2020 12:00:00   16 2020-01-22 12:00:00    Inner Mongolia
# 01/22/2020 12:00:00   17 2020-01-22 12:00:00           Jiangsu
# 01/22/2020 12:00:00   18 2020-01-22 12:00:00           Jiangxi
# 01/22/2020 12:00:00   19 2020-01-22 12:00:00             Jilin
# 01/22/2020 12:00:00   20 2020-01-22 12:00:00          Liaoning
# 01/22/2020 12:00:00   21 2020-01-22 12:00:00             Macau
# 01/22/2020 12:00:00   22 2020-01-22 12:00:00           Ningxia
# 01/22/2020 12:00:00   23 2020-01-22 12:00:00           Qinghai
# 01/22/2020 12:00:00   24 2020-01-22 12:00:00           Shaanxi
# 01/22/2020 12:00:00   25 2020-01-22 12:00:00          Shandong
# 01/22/2020 12:00:00   26 2020-01-22 12:00:00          Shanghai
# 2020-01-29     7783.0   170.0      133.0
# 2020-01-30     9776.0   213.0      187.0
# 2020-01-31    11374.0   259.0      252.0
# 2020-02-01    14549.0   305.0      340.0
# 2020-02-02    17295.0   362.0      487.0
# 2020-02-03    20588.0   426.0      644.0
# 2020-02-04    24503.0   492.0      899.0

# %%
# from plotly.subplots import make_subplots
#fig = make_subplots(rows=1, cols=3, subplot_titles=("Confirmed", "Deaths", "Recovered"))
sns.set(color_codes=True)

plt.subplots(figsize=(10,10))
spread_gl['Confirmed'].plot(style='bs-')
spread_gl['Deaths'].plot(style='ro-')
spread_gl['Recovered'].plot(style='g^-')

# %% [markdown]
# ## 6. Show dependence between confirmed cases and deaths case

# %%
# Dependence between Confirmed and Deaths
sns.set(color_codes=True)

spread_gl.plot(kind='scatter',x='Confirmed', y='Deaths',c = 'r',figsize=(10,10))
#spread_gl.plot(kind='scatter',figsize=(10,10), fontsize=12, style='bs-',x='Confirmed', y='Deaths'  c = 'g')

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(spread_gl['Confirmed'],spread_gl['Deaths'])
intercept,slope
# Out:
# (11.284505993009049, 0.020168749319859545)

# %%
sns.set(color_codes=True)
# y = c + mx
def linefitline(b):
    return intercept + slope * b
line = linefitline(spread_gl['Confirmed'])

plt.scatter(spread_gl['Confirmed'],spread_gl['Deaths'],c = 'r')
plt.xlabel('Confirmed')
plt.ylabel('Deaths')
plt.title('Scatterplot of Confirmed vs Deaths - Linear Regression')
plt.plot(spread_gl['Confirmed'],line, c = 'b')
plt.show()

# %% [markdown]
# ## 7. Show dependence between confirmed cases and recovered case

# %%
sns.set(color_codes=True)

spread_gl.plot(kind='scatter',figsize=(10,10), fontsize=12, style='bs-',x='Confirmed', y='Recovered', c='g')

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(spread_gl['Confirmed'],spread_gl['Recovered'])
intercept,slope
# Out:
# (-58.128076833055815, 0.03321816695576185)

# %%
sns.set(color_codes=True)
# y = c + mx
def linefitline(b):
    return intercept + slope * b
line = linefitline(spread_gl['Confirmed'])

plt.scatter(spread_gl['Confirmed'],spread_gl['Recovered'],c='g')
plt.xlabel('Confirmed')
plt.ylabel('Deaths')
plt.title('Scatterplot of Confirmed vs Deaths - Linear Regression')
plt.plot(spread_gl['Confirmed'],line, c = 'b')
plt.show()

# %%
#r2 = r2_score(y, p(x))
r2 = r2_score(spread_gl['Recovered'],line)
print('The rsquared value is: ' + str(r2))
# Out:
# The rsquared value is: 0.9384390923209045

# %%
x = spread_gl['Confirmed']
y = spread_gl['Recovered']
plt.xlabel('Age (yr)')
plt.ylabel('Length (cm)')
plt.title('Scatterplot of Length vs Age')
a, aa, c= np.polyfit(x,y,2)

def polynomail(b):
    return (b*b*a) +  (b*aa) + c
pline = polynomail(x)


#plt.plot(xp,p(xp),c = 'r')
plt.scatter(x,y,c='g')
plt.plot(x,pline, c = 'b')
plt.show()

# %%
r2 = r2_score(pline,y)
print('The rsquared value is: ' + str(r2))
# Out:
# The rsquared value is: 0.9981281657169362
